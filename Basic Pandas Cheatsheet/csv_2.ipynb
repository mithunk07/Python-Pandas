# %%
import numpy as np
import pandas as pd


data=pd.read_csv(r'C:\Users\MITHUNKUMAR S\Desktop\Jupyter\emp.csv')



data.head()
# Out:
#     Name  Age     Sex
# 0   Mike   23    Male
# 1   Adam   24    Male
# 2    Rob   34    Male
# 3  Carol   32  Female
# 4  Wendy   26  Female

# %% [markdown]
#   * ***To Add new columnn***

# %%
data["graduate"]=["Y","Y","N","Y","N"]
data
# Out:
#     Name  Age     Sex graduate
# 0   Mike   23    Male        Y
# 1   Adam   24    Male        Y
# 2    Rob   34    Male        N
# 3  Carol   32  Female        Y
# 4  Wendy   26  Female        N

# %% [markdown]
#   * To copy the count of the words in a column and create a new column using it

# %%
data["Count"]=data['Name'].str.len()
data
# Out:
#     Name  Age     Sex graduate  Count
# 0   Mike   23    Male        Y      4
# 1   Adam   24    Male        Y      4
# 2    Rob   34    Male        N      3
# 3  Carol   32  Female        Y      5
# 4  Wendy   26  Female        N      5

# %% [markdown]
#   * ***To delete a row***

# %%
data
# Out:
#     Name  Age     Sex graduate  Count
# 0   Mike   23    Male        Y      4
# 1   Adam   24    Male        Y      4
# 2    Rob   34    Male        N      3
# 3  Carol   32  Female        Y      5
# 4  Wendy   26  Female        N      5

# %%
data.drop(data.index[4],inplace=True)
data
# Out:
#     Name  Age     Sex graduate  Count
# 0   Mike   23    Male        Y      4
# 1   Adam   24    Male        Y      4
# 2    Rob   34    Male        N      3
# 3  Carol   32  Female        Y      5

# %% [markdown]
#   * ***To Delete a column***

# %%
del data["Count"]
data
# Out:
#     Name  Age     Sex graduate
# 0   Mike   23    Male        Y
# 1   Adam   24    Male        Y
# 2    Rob   34    Male        N
# 3  Carol   32  Female        Y

# %% [markdown]
#   * ***To add a new row***

# %%
data.loc[4]=["Gary",34,'Male','Y']
data
# Out:
#     Name  Age     Sex graduate
# 0   Mike   23    Male        Y
# 1   Adam   24    Male        Y
# 2    Rob   34    Male        N
# 3  Carol   32  Female        Y
# 4   Gary   34    Male        Y

# %% [markdown]
#   * ***To change/update the values with their index***

# %%
data
# Out:
#     Name   Age     Sex graduate
# 0   Mike    23    Male        Y
# 1   Adam    24    Male        Y
# 2    Rob    34    Male        N
# 3  Carol    32  Female        Y
# 4   Gary  Male      34        Y

# %%
data.iloc[3,0]="Wendy"
data
# Out:
#     Name  Age     Sex graduate
# 0   Mike   23    Male        Y
# 1   Adam   24    Male        Y
# 2    Rob   34    Male        N
# 3  Wendy   32  Female        Y
# 4   Gary   34    Male        Y

# %% [markdown]
#   * ***Sorting***
#
#   We will add a new column called salary and will sort the dataframe according to salary

# %%
data["Salary"]=[2000,3000,1300,3400,1000]
data
# Out:
#     Name  Age     Sex graduate  Salary
# 0   Mike   23    Male        Y    2000
# 1   Adam   24    Male        Y    3000
# 2    Rob   34    Male        N    1300
# 3  Wendy   32  Female        Y    3400
# 4   Gary   34    Male        Y    1000

# %%
data.sort_values(by="Salary")
# Out:
#     Name  Age     Sex graduate  Salary
# 4   Gary   34    Male        Y    1000
# 2    Rob   34    Male        N    1300
# 0   Mike   23    Male        Y    2000
# 1   Adam   24    Male        Y    3000
# 3  Wendy   32  Female        Y    3400

# %% [markdown]
# ***By default it will sort in ascending order, if we want to sort in descending order then we have to give ascending=False***

# %%
data.sort_values("by="Salary",ascending=False")
# Out:
#     Name  Age     Sex graduate  Salary
# 3  Wendy   32  Female        Y    3400
# 1   Adam   24    Male        Y    3000
# 0   Mike   23    Male        Y    2000
# 2    Rob   34    Male        N    1300
# 4   Gary   34    Male        Y    1000

# %% [markdown]
# ***We can also sort multiple columns***

# %%
data.sort_values(by=["Salary","Sex"])
# Out:
#     Name  Age     Sex graduate  Salary
# 3  Wendy   32  Female        Y    3400
# 1   Adam   24    Male        Y    3000
# 0   Mike   23    Male        Y    2000
# 2    Rob   34    Male        N    1300
# 4   Gary   34    Male        Y    1000
